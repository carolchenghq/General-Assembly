# %% [markdown]
# ## Scrape job postings data from the website Seek.com

# %%
import requests
from bs4 import BeautifulSoup

# %%
# Define search_terms
search_terms = [["data","engineer"],["data","scientist"],["analyst","data"], ["business","intelligence"],
                ["machine learning","engineer"],["quantitative","analyst"], ["data","warehouse","architect"]]

# Calculate the number of pages for each search_term
num_list = []
for search_term in search_terms:
    search_url = "https://www.seek.com.au/" + "-".join(search_term) + "-jobs"
    response_search = requests.get(search_url)
    html_search = response_search.text
    soup_search = BeautifulSoup(html_search, 'lxml')
    # find the content that indicates the total jobs count for the search result
    count_str = soup_search.select_one('strong[data-automation="totalJobsCount"]').text.replace(',', '')
    # calculate the possible number of pages for the search result(average 20 job postings each page)
    num_of_pages = int(int(count_str) / 20)
    num_list.append(num_of_pages)
    
num_list
# Out:
# [188, 30, 132, 143, 19, 11, 8]

# %%
# Find out the url for each job posting, store them in a list.
posting_urls = []
for i in range(len(num_list)):
    for n in range(1, num_list[i]+1):
        page_url = "https://www.seek.com.au/" + "-".join(search_terms[i]) + "-jobs?page=" + str(n)
        response_page = requests.get(page_url)
        html = response_page.text
        soup = BeautifulSoup(html, 'lxml')
        
        anchors = soup.find_all('a',{'class':'_2iNL7wI'})
        url_base='https://www.seek.com.au'
        for anchor in anchors:
            posting_urls.append(url_base + anchor.get('href'))

# %%
# Check how many job postings I have got.
len(posting_urls)
# Out:
# 10695

# %%
# store the posting_urls into a dataframe so that I can export it for further use.
import pandas as pd
df_urls = pd.DataFrame(data=posting_urls, columns=['url'])
df_urls.head()
df_urls.to_csv('posting_urls')

# %%
from multiprocessing import Pool
import sys
import time
import traceback

sys.setrecursionlimit(30000)

allJobs = {}
failedUrls = []

def extractJobId(url):
    prefix_len = len('https://www.seek.com.au/job/')
    q_index = url.index('?')
    return url[prefix_len:q_index]

    
def fetchJob(url):
    job = {}


    try:
        job['job_id'] = extractJobId(url)
        posting_resp = requests.get(url)
        posting_html = posting_resp.text
        postingSoup = BeautifulSoup(posting_html, 'lxml')
        
        job['job_title'] = postingSoup.select_one('span[data-automation="job-detail-title"] h1').text    
        job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
        section = postingSoup.select_one('article[aria-labelledby="jobDescription"] section[aria-labelledby="jobInfoHeader"]')
        job['posted_date'] = section.select_one('dd[data-automation="job-detail-date"] span.lwHBT6d').text
        
        locationDD = section.select_one('dd[data-automation="job-detail-date"] + dt + dd')   
        job['city'] = locationDD.select_one('strong').text
        job['job_type'] = section.select_one('dd[data-automation="job-detail-work-type"]> span > span').text
        
        classificationDD = section.select_one('dd[data-automation="job-detail-work-type"] + div dd')
        job['classification'] = classificationDD.select_one('strong').text
    except Exception as e:
        traceback.print_exc()
        failedUrls.append(url)
        return {}

    try: 
        job['suburb'] = locationDD.select_one('span > span > span').contents[1]
    except:
        job['suburb'] = ''

    try:
        job['salary'] = section.select_one('dl > div span[class="lwHBT6d"]').text
    except:
        job['salary'] = ''
          
    try:
        section = postingSoup.select_one('article[aria-labelledby="jobDescription"] section[aria-labelledby="jobInfoHeader"]')
        classificationDD = section.select_one('dd[data-automation="job-detail-work-type"] + div dd')
        job['subclassification'] = classificationDD.select_one('span > span > span').contents[1]
    except:
        job['subclassification'] = ''
    try:
        job['recruiter_rating'] = postingSoup.select_one('span[data-automation="job-header-company-review-title"] + span span._1erK2ob').contents[0]
    except:
        job['recruiter_rating'] = ''

    try:
        job['description'] = postingSoup.select_one('div[data-automation="jobDescription"] div[data-automation="mobileTemplate"]').text
    except:
        job['description'] = ''
    return job

# %%
def fetchJobs(start, end):
    for url in posting_urls[start:end]:
        job = fetchJob(url)
        if job:
            allJobs[job['job_id']] = job

fetchJobs(0, 10695)

print("AllJobs:", len(allJobs))
print("FailedURLs:", failedUrls)
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# Traceback (most recent call last):
#   File "<ipython-input-54-32b914f58bfa>", line 28, in fetchJob
#     job['recruiter'] = postingSoup.select_one('span[class="_3FrNV7v _2QG7TNq E6m4BZb"] span').text
# AttributeError: 'NoneType' object has no attribute 'text'
# AllJobs: 7818
# FailedURLs: ['https://www.seek.com.au/job/40918623?type=standard#searchRequestToken=98e46458-12df-4de7-a85e-bd38e1074817', 'https://www.seek.com.au/job/40842834?type=standard#searchRequestToken=aba23ccc-8ca4-4d1b-a314-e525e3d363dd', 'https://www.seek.com.au/job/40918623?type=standard#searchRequestToken=98e46458-12df-4de7-a85e-bd38e1074817', 'https://www.seek.com.au/job/40842834?type=standard#searchRequestToken=aba23ccc-8ca4-4d1b-a314-e525e3d363dd', 'https://www.seek.com.au/job/40878511?type=standard#searchRequestToken=ca51fa32-91d9-4e0c-a4ba-3f5e2933a6d6', 'https://www.seek.com.au/job/40916466?type=standard#searchRequestToken=60da5cc3-56e1-4135-b939-44fa9248433f', 'https://www.seek.com.au/job/40849022?type=standout#searchRequestToken=8caed537-0ec3-46b9-abb5-b8a86f6bf897', 'https://www.seek.com.au/job/40806877?type=standard#searchRequestToken=342203cb-3ef3-4e15-9a1a-e662c94d51be', 'https://www.seek.com.au/job/40882223?type=standard#searchRequestToken=f96fda3c-44b2-4ec6-bc80-ebfb92b36cb3', 'https://www.seek.com.au/job/40839407?type=standard#searchRequestToken=99aa4dcc-632a-41ca-b611-283400c5ee91', 'https://www.seek.com.au/job/40894171?type=standard#searchRequestToken=24df20a4-1716-47dd-b91e-7851cd9bf77f', 'https://www.seek.com.au/job/40887215?type=standard#searchRequestToken=6cb0af73-5e7e-408f-ba5d-34d4e7e47345', 'https://www.seek.com.au/job/40633140?type=standout#searchRequestToken=c75dd202-4621-4bc6-9aec-cb2ee73ef04d', 'https://www.seek.com.au/job/40863882?type=standard#searchRequestToken=ad0ce5d0-681a-4a45-9437-a017d248c908', 'https://www.seek.com.au/job/40914083?type=standard#searchRequestToken=1cdcce17-6483-4282-92cc-af50bced744d', 'https://www.seek.com.au/job/40912624?type=standard#searchRequestToken=67648b29-65f4-4085-ab04-eec26a821d4d', 'https://www.seek.com.au/job/40839341?type=standard#searchRequestToken=2b220790-8b5e-4814-b01f-2647da44c766', 'https://www.seek.com.au/job/40908192?type=standout#searchRequestToken=9d7409ea-6f4b-4052-9691-4a521e34dcb7', 'https://www.seek.com.au/job/40826015?type=standard#searchRequestToken=eb02360b-2552-426c-899f-12b0672844e0', 'https://www.seek.com.au/job/40862521?type=standard#searchRequestToken=0d2e91bf-dd42-4c80-aa82-7001d966b916', 'https://www.seek.com.au/job/40893577?type=standout#searchRequestToken=9ed3769a-7875-42da-961f-383c5c428a57', 'https://www.seek.com.au/job/40755567?type=standard#searchRequestToken=cc530ed0-b635-49b0-99f5-d9ba3e36f893', 'https://www.seek.com.au/job/40743271?type=standard#searchRequestToken=3f36d533-33df-49a7-920d-9c01e72a8d3c', 'https://www.seek.com.au/job/40883749?type=standard#searchRequestToken=61320f49-02da-4079-8e40-1578f19ddc84', 'https://www.seek.com.au/job/40802813?type=standout#searchRequestToken=8b72a829-b5f1-4a67-a92a-0033917673b4', 'https://www.seek.com.au/job/40856854?type=standout#searchRequestToken=8b72a829-b5f1-4a67-a92a-0033917673b4', 'https://www.seek.com.au/job/40717901?type=standard#searchRequestToken=f2ddb9ca-9ddf-47a7-9686-50c16062402e', 'https://www.seek.com.au/job/40799751?type=standout#searchRequestToken=71123304-e5a9-4485-816b-d0aab0423e88', 'https://www.seek.com.au/job/40814031?type=standout#searchRequestToken=7232321b-2d37-4a0f-9f5d-237690875f4d', 'https://www.seek.com.au/job/40724901?type=standout#searchRequestToken=cd1d14a1-392a-4b27-a3e4-bf960301704a', 'https://www.seek.com.au/job/40767521?type=standard#searchRequestToken=53c4f840-eefb-4893-ab1f-c8dc9ac290dc', 'https://www.seek.com.au/job/40767501?type=standard#searchRequestToken=53c4f840-eefb-4893-ab1f-c8dc9ac290dc', 'https://www.seek.com.au/job/40808538?type=standard#searchRequestToken=074543f4-33ce-4ad1-bad7-e9c775cd26d2', 'https://www.seek.com.au/job/40832773?type=standard#searchRequestToken=46b41f8f-e05e-4fd8-bb12-697126846519', 'https://www.seek.com.au/job/40908664?type=standard#searchRequestToken=40e134d8-79e6-478e-a922-82962d1b9ed6', 'https://www.seek.com.au/job/40911331?type=standard#searchRequestToken=9f0fab94-9baf-4ea0-a84e-0d3bce71875f', 'https://www.seek.com.au/jo ...

# %%
# Convert the dictionary allJobs to a dataframe

df_all_jobs = pd.DataFrame.from_dict(allJobs, orient='index')
df_all_jobs.head()
# Out:
#             job_id                                     job_title  \
# 40771115  40771115                                 Python Expert
# 40855053  40855053  Operations Command Center Engineer T2 - Data
# 40925581  40925581                                 Data Engineer
# 40925535  40925535                                 Data Engineer
# 40924597  40924597                                Data Engineer
#
#                    recruiter  posted_date       city       job_type  \
# 40771115            Atlastix  19 Jan 2020  Melbourne  Contract/Temp
# 40855053     The Vocus Group  31 Jan 2020  Melbourne      Full Time
# 40925581           The Onset  10 Feb 2020     Sydney      Full Time
# 40925535     Allura Partners  10 Feb 2020     Sydney      Full Time
# 40924597  Precision Sourcing  10 Feb 2020     Sydney      Full Time
#
#                                   classification  \
# 40771115                    Science & Technology
# 40855053  Information & Communication Technology
# 40925581  Information & Communication Technology
# 40925535  Information & Communication Technology
# 40924597  Information & Communication Technology
#
#                                      suburb                    salary  \
# 40771115                CBD & Inner Suburbs
# 40855053                CBD & Inner Suburbs
# 40925581  CBD, Inner West & Eastern Suburbs  $170,000 + Super + Bonus
# 40925535  CBD, Inner West & Eastern Suburbs
# 40924597                                           $110k - $120k p.a.
#
#                                        subclassification recruiter_rating  \
# 40771115  Mathematics, Statistics & Information Sciences
# 40855053                              Telecommunications              2.8
# 40925581                          Engineering - Software
# 40925535           Database Development & Administration
# 40924597                          Developers/Programmers
#
#                                                 description
# 40771115  Are you a gun coder with a deep appreciation o...
# 40855053   Do you love technology, network operations an...
# 40925581  It's your call whether to garner support from ...
# 40925535  As a Junior Data Scientist, you will focus on ...
# 40924597  About the business  This is an amazing time to...

# %%
# Save the dataframe as a csv file so that I can use it for analysis later (When next time I open the notebook, 
# I don't have to re-run the code to scrap the data again)
df_all_jobs.to_csv('Data_jobs_full_version.csv')
